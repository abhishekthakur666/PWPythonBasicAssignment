# %%
 #1. Explain the key features of Python that make it a popular choice for Programming
    
    # Python programming syntax resembles simple english and hence easy to program
    # Language is intepreted than compiled, hence setup is easy unlike java which needs compilation/Runtime enviornment
    # Though Programming language supports Object orientation, it doesn't mandate users to write code in oop style
    # No complex memory management, unlike c/c++ which needs to be tracked for object space allocation/release
    # Implementation of datastructures are comparively simple for list, dictionary, set etc
    # Python Code can be easily ported accross operating system, without need of understanding unlying OS/CPU arch
    # Python3 specially has achieved good benchmark in terms of processing performance, equivalent of other low level languages like golang

# %%
#2. Describe the role of predefined keywords in Python and provide examples of how they are used in a program.

    # Predefined keywords builds the syntax of language for various requirements as illustrated below
    # 1.Iteration - 
                # 1.1  for i in x:
                # 1.2  while True:
    # 2.Exception handling - 
                # try:
                  # ...
                # except Exception as ex:
                  # ...
                # finally:
                  #...
    # 3.Construction / Descructor -   
                 # class x:
                   # def __init__(self):
                      # ....
                   # def __del__(self)
                      # ....
    #4. Conditional - And, or etc
                 # x and y, x or y, not x

# %%
#3. Compare and contrast Mutable and immutable objects in Python with exmples

   # Immutuable objects in python - 
     # 1.Objects that cannot be modified post it's creation e.g. primitive objects like string, int, bool, tuple etc
     # 2.Objects are hashable and can be used as key for a dictionary or an item for a set
     # 3. e.g.   # test_dict = {}
                 # x  = (1,2,3)
                 # test_dict[x] = "hello"  # here x (tuple) is used as a key for dictionary
  # Mutable objects in python
    # 1.Objects that can be modified post it's creation e.g. list, set, dictionary
    # 2.Recommended to use when size is not fixed and can be incremented/decremented
    # 3. e.g.  # test_dict = {"a" : 1, "b" : 2}
               # test_dict["c"] = 3     # Addition of entry
               # del test_dict["b"]     # Removal of entry

# %%
#4. Discuss the different types of operators in Python and provide examples of how they are used

    #1. Logical operators - and, or, not 
        # e.g. True and False -> False
        # e.g. True or False -> True
        # e.g. not True   -> False
        
    #2. Membership operators - in, not in
       # e.g. x = {"a"  :  1 }
       # "a" in x -> True
       # "a" not in x -> False
    
    #3. Identity operators - is, is not
      # e.g x = "Bob"
      # x is "alice" -> False
      # x is "Bob" -> True
        
    #4.Bitwise Operators ->
      # 4.1 -> & (AND) -> Both bits must be 1 to change resultant bit to 1
      # 4.2 -> | (OR), -> Atleast one bit must be 1 to change resultant bit to 1 
      # 4.3 -> ^ (XOR) -> Either one of the 2 bits must be 1, to change resultant bit to 1
      # 4.4 -> ~ (NOT) -> Reverts bit from 1 to 0 and vice-versa

# %%
# 5. Explain the concept of type casting in Python with examples
  # Changes type from one type to other - as long as conversion is possible, else exception is raised
    # 5.1 Integer type casting from string ->
      # e.g. x = "5"
      #     y = int(x) -> y = 5
    # 5.2 String type casting from integer ->
      # e.g. x = 50
      #       y = str(x) -> y = "50"
    # 5.3 Object casting to string using __str__ method:
      # e.g. class X:
      #         int y = 10000
      #         def __str__(self):
      #              return str(y)
      #       obj = X()
      #       print(obj) -> "10000"

# %%
#6. How do conditional statements work in Python? Illustrate with examples
    # 6.1  - if condition
    #      e.g if True -> True
    #
    # 6.2 - if / else condition
    #       e.g. if 0:
    #              print("x")
    #            else:
    #              print("y")  --> Will print "y"
    #6.3 - multiple if with else
    #      e.g if  0:
    #              print("a")
    #          elif False:
    #              print("b")
    #          elif True:
    #              print("c")   --> Will print "c"
    #          else True:
    #              print("d")  
    #
    #6.4 - Ternary conditional
    #    e.g. x = [1, 2, 3, 4]
    #         y = True if len(x) >= 4 else False
    #         print(y) --> True

# %%
#7. Describe the different types of loops in Python and their use cases with examples.

   #7.1 for loop 
      # for ierator in sequence:
      # e.g. x = [1, 2, 3, 4]
      #      for i in x:
      #           print(i)  #1, 2, 3, 4
    
      # e.g. for i in range(5)
      #           print(i)  #0, 1, 2, 3, 4
    
   #7.2 while loop
     # while condition is true:
     # e.g. _max = 10 
     #      x = 1
     #      while x < _max:
     #          print(x)
     #          x += 1
